# %%
# !uv pip install notebook duckdb pandas fastparquet semsimian
# Out:
# Audited 5 packages in 26ms

# %% [markdown]
# Download and unzip the Monarch Graph and Phenio semantic SQL datbabase

# %%
# !wget https://data.monarchinitiative.org/monarch-kg/latest/monarch-kg.duckdb.gz
# !gunzip monarch-kg.duckdb.gz
# !wget https://data.monarchinitiative.org/monarch-kg/latest/phenio.db.gz # consider hpo.db.gz for speed
# !gunzip phenio.db.gz
# Out:
# --2024-11-11 12:18:54--  https://data.monarchinitiative.org/monarch-kg/latest/monarch-kg.duckdb.gz
# Resolving data.monarchinitiative.org (data.monarchinitiative.org)... 35.208.191.193
# Connecting to data.monarchinitiative.org (data.monarchinitiative.org)|35.208.191.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1628735176 (1.5G) [application/octet-stream]
# Saving to: ‘monarch-kg.duckdb.gz’
#
# monarch-kg.duckdb.g 100%[===================>]   1.52G  33.1MB/s    in 49s
#
# 2024-11-11 12:19:44 (31.5 MB/s) - ‘monarch-kg.duckdb.gz’ saved [1628735176/1628735176]
#
# monarch-kg.duckdb already exists -- do you wish to overwrite (y or n)?

# %%
import duckdb

db = duckdb.connect('monarch-kg.duckdb', read_only=True)
db.sql("""
copy (
  select 
       subject as disease, 
       list(object) as phenotype, 
       primary_knowledge_source as source
    from edges
  where predicate = 'biolink:has_phenotype' 
       and negated <> True
       and primary_knowledge_source in ('infores:orphanet','infores:omim')
       and subject in (
          select distinct subject
            from denormalized_edges
            where subject_namespace = 'MONDO'
              and predicate = 'biolink:has_phenotype'
              and primary_knowledge_source in ('infores:orphanet','infores:omim')
            group by all
            having count(distinct primary_knowledge_source) > 1
       )     
    group by all
) to 'phenotype_profiles_by_source.parquet';       
""")

# %%
# load the phenotype profiles into a pandas dataframe 
import pandas as pd
phenotype_profiles = pd.read_parquet('phenotype_profiles_by_source.parquet')
phenotype_profiles.head()
# Out:
#          disease                                          phenotype  \
# 0  MONDO:0007167  [HP:0000774, HP:0001156, HP:0001762, HP:000208...
# 1  MONDO:0008967  [HP:0003236, HP:0005978, HP:0011892, HP:003051...
# 2  MONDO:0010547  [HP:0002073, HP:0000639, HP:0001152, HP:000127...
# 3  MONDO:0008829  [HP:0000501, HP:0001004, HP:0001482, HP:000154...
# 4  MONDO:0008620               [HP:0002986, HP:0003022, HP:0009465]
#
#              source
# 0  infores:orphanet
# 1  infores:orphanet
# 2  infores:orphanet
# 3  infores:orphanet
# 4  infores:orphanet

# %% [markdown]
# Initialize semsimian from phenio.db

# %%
from semsimian import Semsimian

predicates= [
    "rdfs:subClassOf",
    "BFO:0000050",
    "UPHENO:0000001",
]

semsimian = Semsimian(
    spo=None,
    predicates=predicates,
    pairwise_similarity_attributes=None,
    resource_path="./phenio.db",
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 31
#      27     print(f'No Orphanet profile for {disease}, skipping')
#      28     continue
# ---> 31 semsimian.termset_comparison(
#      32     omim_profile, orphanet_profile, 'ancestor_information_content'
#      33 )
#
# TypeError: argument 'subject_terms': 'list' object cannot be converted to 'PySet'

# %% [markdown]
# Using Semsimian, generate termset_pairwise_similarity scores for OMIM vs Orphanet, OMIM vs OMIM and Orphanet vs Orphanet using each metric.

# %%
results = []
for disease in phenotype_profiles['disease'].unique():
    result = {
        'disease': disease
    }
    # get the omim profile
    try:
        omim_profile = list(phenotype_profiles[(phenotype_profiles['disease'] == disease) & (phenotype_profiles['source'] == 'infores:omim')]['phenotype'])[0]
    except IndexError:
        print(f'No OMIM profile for {disease}, skipping')
        continue
    # get the orphanet profile
    try:
        orphanet_profile = list(phenotype_profiles[(phenotype_profiles['disease'] == disease) & (phenotype_profiles['source'] == 'infores:orphanet')]['phenotype'])[0]
    except IndexError:
        print(f'No Orphanet profile for {disease}, skipping')
        continue

    for metric in ['ancestor_information_content', 'jaccard_similarity', 'phenodigm_score']:                
        result[metric] = pairwise_similarity_result = semsimian.termset_pairwise_similarity(
            set(omim_profile), set(orphanet_profile), metric
        )
        result[f"omim_self_{metric}"] = semsimian.termset_pairwise_similarity(
            set(omim_profile), set(omim_profile), metric
        )
        result[f"orphanet_self_{metric}"] = semsimian.termset_pairwise_similarity(
            set(orphanet_profile), set(orphanet_profile), metric
        )

    results.append(result)
# Out:
# No OMIM profile for MONDO:0017324, skipping
# No OMIM profile for MONDO:0016241, skipping
# No OMIM profile for MONDO:0018852, skipping
# No OMIM profile for MONDO:0033925, skipping
# No OMIM profile for MONDO:0018705, skipping
# No OMIM profile for MONDO:0015826, skipping
# No Orphanet profile for MONDO:0008856, skipping
# No Orphanet profile for MONDO:0010024, skipping
# No Orphanet profile for MONDO:0007597, skipping
# No Orphanet profile for MONDO:0007091, skipping
# No Orphanet profile for MONDO:0007447, skipping
# No Orphanet profile for MONDO:0007186, skipping
# No Orphanet profile for MONDO:0060650, skipping
# No Orphanet profile for MONDO:0007810, skipping
# No Orphanet profile for MONDO:0014912, skipping
# No Orphanet profile for MONDO:0014784, skipping
# No Orphanet profile for MONDO:0013754, skipping
# No Orphanet profile for MONDO:0013519, skipping
# No Orphanet profile for MONDO:0008787, skipping
# No Orphanet profile for MONDO:0010520, skipping
# No OMIM profile for MONDO:0002413, skipping
# No OMIM profile for MONDO:0017838, skipping
# No OMIM profile for MONDO:0019130, skipping
# No OMIM profile for MONDO:0019975, skipping
# No OMIM profile for MONDO:0016085, skipping
# No OMIM profile for MONDO:0005761, skipping
# No OMIM profile for MONDO:0017869, skipping
# No OMIM profile for MONDO:0033672, skipping
# No OMIM profile for MONDO:0017794, skipping
# No OMIM profile for MONDO:0007526, skipping
# No OMIM profile for MONDO:0019345, skipping
# No OMIM profile for MONDO:0020367, skipping
# No OMIM profile for MONDO:0019019, skipping
# No OMIM profile for MONDO:0019016, skipping
# No OMIM profile for MONDO:0018242, skipping
# No OMIM profile for MONDO:0017416, skipping
# No OMIM profile for MONDO:0018940, skipping
# No OMIM profile for MONDO:0016810, skipping
# No OMIM profile for MONDO:0016158, skipping
# No OMIM profile for MONDO:0018092, skipping
# No OMIM profile for MONDO:0019209, skipping
# No OMIM profile for MONDO:0015661, skipping
# No OMIM profile for MONDO:0005619, skipping
# No OMIM profile for MONDO:0018458, skipping
# No OMIM profile for MONDO:0015780, skipping
# No Orphanet profile for MONDO:0009943, skipping
# No Orphanet profile for MONDO:0005260, skipping
# No Orphanet profile for MONDO:0009087, skipping
# No Orphanet profile for MONDO:0008422, skipping
# No Orphanet profile for MONDO:0001046, skipping
# No Orphanet profile for MONDO:0014118, skipping
# No Orphanet profile for MONDO:0009715, skipping
# No Orphanet profile for MONDO:0005147, skipping
# No Orphanet profile for MONDO:0008158, skipping
# No Orphanet profile for MONDO:0010222, skipping
# No Orphanet profile for MONDO:0007361, skipping
# No Orphanet profile for MONDO:0014280, skipping
# No Orphanet profile for MONDO:0020746, skipping
# No Orphanet profile for MONDO:0008338, skipping
# No Orphanet profile for MONDO:0009852, skipping
# No OMIM profile for MONDO:0016364, skipping
# No OMIM profile for MONDO:0016826, skipping
# No OMIM profile for MONDO:0008891, skipping
# No OMIM profile for MONDO:0015806, skipping
# No OMIM profile for MONDO:0011020, skipping
# No OMIM profile for MONDO:0017199, skipping
# No OMIM profile for MONDO:0017409, skipping
# No OMIM profile for MONDO:0016981, skipping
# No OMIM profile for MONDO:0018071, skipping
# No OMIM profile for MONDO:0017405, skipping
# No OMIM profile for MONDO:0019571, skipping
# No OMIM profile for MONDO:0005136, skipping
# No OMIM profile for MONDO:0019190, skipping
# No OMIM profile for MONDO:0018661, skipping
# No OMIM profile for MONDO:0018105, skipping
# No OMIM profile for MONDO:0011620, skipping
# No Orphanet profile for MONDO:0100428, skipping
# No Orphanet profile for MONDO:0007086, skipping
# No Orphanet profile for MONDO:0010420, skipping
# No Orphanet profile for MONDO:0100211, skipping
# No Orphanet profile for MONDO:0010626, skipping
# No Orphanet profile for MONDO:0018874, skipping
# No Orphanet profile for MONDO:0007594, skipping
# No Orphanet profile for MONDO:0013722, skipping
# No Orphanet profile for MONDO:0007524, skipping
# No Orphanet profile for MONDO:0007595, skipping
# No Orphanet profile for MONDO:0009572, skipping
# No Orphanet profile for MONDO:0009968, skipping
# No Orphanet profile for MONDO:0012933, skipping
# No Orphanet profile for MONDO:0012930, skipping
# No OMIM profile for MONDO:0018334, skipping
# No OMIM profile for MONDO:0000463, skipping
# No OMIM profile for MONDO:0020702, skipping
# No OMIM profile for MONDO:0015804, skipping
# No OMIM profile for MONDO:0017979, skipping
# No OMIM profile for MONDO:0008975, skipping
# No OMIM profile for MONDO:0001881, skipping
# No OMIM profile for MONDO:0005661, skipping
# No OMIM profile for MONDO:0011501, skipping
# No OMIM profile for MONDO:0017161, skipping
# No OMIM profile for MONDO:0025514, skipping
# No OMIM profile for MONDO:0019444, skipping
# No OMIM profile for MONDO:0019152, skipping
# No OMIM profile for MONDO:0019524, skipping
# No OMIM profile for MONDO:0015738, skipping
# No OMIM profile for MONDO:0010680, skipping
# No OMIM profile for MONDO:0010586, skipping
# No OMIM profile for MONDO:0018572, skipping
# No OMIM profile for MONDO:0018702, skipping
# No OMIM profile for MONDO:0018467, skipping
# No OMIM profile for MONDO:0015666, skipping
# No OMIM profile for MONDO:0018493, skipping
# No OMIM profile for MONDO:0019725, skipping
# No Orphanet profile for MONDO:0017790, skipping
# No Orphanet profile for MONDO:0100058, skipping
# No Orphanet profile for MONDO:0020108, skipping
# No Orphanet profile for MONDO:0013316, skipping
# No Orphanet profile for MONDO:0014706, skipping
# No Orphanet profile for MONDO:0010778, skipping
# No Orphanet profile for MONDO:0009768, skipping
# No Orphanet profile for MONDO:0014224, skipping
# No Orphanet profile for MONDO:0009097, skipping
# No Orphanet profile for MONDO:0010072, skipping
# No Orphanet profile for MONDO:0011203, skipping
# No Orphanet profile for MONDO:0007982, skipping
# No Orphanet profile for MONDO:0007850, skipping
# No Orphanet profile for MONDO:0033281, skipping
# No OMIM profile for MONDO:8000010, skipping
# No OMIM profile for MONDO:0019131, skipping
# No OMIM profile for MONDO:0020501, skipping
# No OMIM profile for MONDO:0005502, skipping
# No OMIM profile for MONDO:0020502, skipping
# No OMIM profile for MONDO:0015465, skipping
# No OMIM profile for MONDO:0007473, skipping
# No OMIM profile for MONDO:0018072, skipping
# No OMIM profile for MONDO:0018068, skipping
# No OMIM profile for MONDO:0018065, skipping
# No OMIM profile for MONDO:0015517, skipping
# No OMIM profile for MONDO:0018055, skipping
# No OMIM profile for MONDO:0019443, skipping
# No OMIM profile for MONDO:0008389, skipping
# No OMIM profile for MONDO:0017395, skipping
# No OMIM profile for MONDO:0019632, skipping
# No OMIM profile for MONDO:0016086, skipping
# No OMIM profile for MONDO:0004976, skipping
# No OMIM profile for MONDO:0017723, skipping
# No OMIM profile for MONDO:0019026, skipping
# No OMIM profile for MONDO:0016089, skipping
# No OMIM profile for MONDO:0004691, skipping
# No OMIM profile for MONDO:0018950, skipping
# No OMIM profile for MONDO:0009563, skipping
# No OMIM profile for MONDO:0016331, skipping
# No Orphanet profile for MONDO:0010541, skipping
# No Orphanet profile for MONDO:0009088, skipping
# No Orphanet profile for MONDO:0009052, skipping
# No Orphanet profile for MONDO:0008409, skipping
# No Orphanet profile for MONDO:0014614, skipping
# No Orphanet profile for MONDO:0013170, skipping
# No Orphanet profile for MONDO:0014690, skipping
# No Orphanet profile for MONDO:0013931, skipping
# No Orphanet profile for MONDO:0007104, skipping
# No Orphanet profile for MONDO:0009356, skipping
# No OMIM profile for MONDO:0016619, skipping
# No OMIM profile for MONDO:0008686, skipping
# No OMIM profile for MONDO:0007614, skipping
# No OMIM profile for MONDO:0016006, skipping
# No OMIM profile for MONDO:0016660, skipping
# No OMIM profile for MONDO:0018006, skipping
# No OMIM profile for MONDO:0015282, skipping
# No OMIM profile for MONDO:0015884, skipping
# No OMIM profile for MONDO:0019186, skipping
# No OMIM profile for MONDO:0017941, skipping
# No OMIM profile for MONDO:0010180, skipping
# No OMIM profile for MONDO:0008947, skipping
# No OMIM profile for MONDO:0008223, skipping
# No OMIM profile for MONDO:0008003, skipping
# No OMIM profile for MONDO:0018094, skipping
# No OMIM profile for MONDO:0005091, skipping
# No OMIM profile for MONDO:0018800, skipping
# No Orphanet profile for MONDO:0013956, skipping
# No Orphanet profile for MONDO:0007181, skipping
# No Orphanet profile for MONDO:0027676, skipping
# No Orphanet profile for MONDO:0010584, skipping
# No Orphanet profile for MONDO:0014076, skipping
# No Orphanet profile for MONDO:0010358, skipping
# No Orphanet profile for MONDO:0010737, skipping
# No Orphanet profile for MONDO:0008410, skipping
# No Orphanet profile for MONDO:0009080, skipping
# No Orphanet profile for MONDO:0011014, skipping
# No Orphanet profile for MONDO:0010761, skipping
# No Orphanet profile for MONDO:0009035, skipping
# No Orphanet profile for MONDO:0007321, skipping
# No Orphanet profile for MONDO:0010338, skipping
# No Orphanet profile for MONDO:0010979, skipping
# No Orphanet profile for MONDO:0012497, skipping
# No Orphanet profile for MONDO:0011422, skipping
# No Orphanet profile for MONDO:0010933, skipping
# No Orphanet profile for MONDO:0014276, skipping
# No Orphanet profile for MONDO:0008046, skipping
# No OMIM profile for MONDO:0016453, skipping
# No OMIM profile for MONDO:0015452, skipping
# No OMIM profile for MONDO:0017572, skipping
# No OMIM profile for MONDO:0016535, skipping
# No OMIM profile for MONDO:0010816, skipping
# No OMIM profile for MONDO:0015943, skipping
# No OMIM profile for MONDO:0007988, skipping
# No OMIM profile for MONDO:0002457, skipping
# No OMIM profile for MONDO:0019508, skipping
# No OMIM profile for MONDO:0019648, skipping
# No OMIM profile for MONDO:0020336, skipping
# No OMIM profile for MONDO:0015705, skipping
# No OMIM profile for MONDO:0005797, skipping
# No OMIM profile for MONDO:0009889, skipping
# No OMIM profile for MONDO:0018695, skipping
# No OMIM profile for MONDO:0016091, skipping
# No OMIM profile for MONDO:0018543, skipping
# No OMIM profile for MONDO:0018570, skipping
# No OMIM profile for MONDO:0018408, skipping
# No Orphanet profile for MONDO:0013520, skipping
# No Orphanet profile for MONDO:0010400, skipping
# No Orphanet profile for MONDO:0008903, skipping
# No Orphanet profile for MONDO:0007092, skipping
# No Orphanet profile for MONDO:0010895, skipping
# No Orphanet profile for MONDO:0008321, skipping
# No Orphanet profile for MONDO:0004980, skipping
# No Orphanet profile for MONDO:0005148, skipping
# No Orphanet profile for MONDO:0008762, skipping
# No Orphanet profile for MONDO:0012851, skipping
# No Orphanet profile for MONDO:0013930, skipping
# No Orphanet profile for MONDO:0007179, skipping
# No Orphanet profile for MONDO:0008368, skipping
# No OMIM profile for MONDO:0017197, skipping
# No OMIM profile for MONDO:0017195, skipping
# No OMIM profile for MONDO:0001595, skipping
# No OMIM profile for MONDO:0011810, skipping
# No OMIM profile for MONDO:0005459, skipping
# No OMIM profile for MONDO:0015776, skipping
# No OMIM profile for MONDO:0005737, skipping
# No OMIM profile for MONDO:0016090, skipping
# No OMIM profile for MONDO:0016264, skipping
# No OMIM profile for MONDO:0018696, skipping
# No OMIM profile for MONDO:0010826, skipping
# No OMIM profile for MONDO:0008742, skipping
# No OMIM profile for MONDO:0007396, skipping
# No Orphanet profile for MONDO:0007661, skipping
# No Orphanet profile for MONDO:0014061, skipping
# No Orphanet profile for MONDO:0008383, skipping
# No Orphanet profile for MONDO:0014821, skipping
# No Orphanet profile for MONDO:0009081, skipping
# No Orphanet profile for MONDO:0007765, skipping
# No Orphanet profile for MONDO:0010716, skipping
# No Orphanet profile for MONDO:0008638, skipping
# No Orphanet profile for MONDO:0010162, skipping
# No Orphanet profile for MONDO:0013521, skipping
# No Orphanet profile for MONDO:0008474, skipping
# No Orphanet profile for MONDO:0700060, skipping
# No Orphanet profile for MONDO:0012868, skipping
# No Orphanet profile for MONDO:0008039, skipping
# No Orphanet profile for MONDO:0012850, skipping
# No Orphanet profile for MONDO:0013522, skipping
# No Orphanet profile for MONDO:0014456, skipping
# No Orphanet profile for MONDO:0007599, skipping
# No Orphanet profile for MONDO:0009783, skipping
# No Orphanet profile for MONDO:0013870, skipping
# No Orphanet profile for MONDO:0033004, skipping
# No Orphanet profile for MONDO:0014865, skipping
# No OMIM profile for MONDO:0017842, skipping
# No OMIM profile for MONDO:0016620, skipping
# No OMIM profile for MONDO:0016472, skipping
# No OMIM profile for MONDO:0018214, skipping
# No OMIM profile for MONDO:0018027, skipping
# No OMIM profile for MONDO:0008867, skipping
# No OMIM profile for MONDO:0015739, skipping
# No OMIM profile for MONDO:0015264, skipping
# No OMIM profile for MONDO:0018353, skipping
# No OMIM profile for MONDO:0019173, skipping
# No OMIM profile for MONDO:0100130, skipping
# No OMIM profile for MONDO:0019037, skipping
# No OMIM profile for MONDO:0019095, skipping

# %%
score_df = pd.DataFrame(
    [{
        'disease': r['disease'],
        'ancestor_information_content': r['ancestor_information_content']['average_score'],
        'ancestor_information_content_omim_self': r['omim_self_ancestor_information_content']['average_score'],
        'ancestor_information_content_orphanet_self': r['orphanet_self_ancestor_information_content']['average_score'],   
        'jaccard_similarity': r['jaccard_similarity']['average_score'],
        'jaccard_similarity_omim_self': r['omim_self_jaccard_similarity']['average_score'],
        'jaccard_similarity_orphanet_self': r['orphanet_self_jaccard_similarity']['average_score'],
        'phenodigm_score': r['phenodigm_score']['average_score'],
        'phenodigm_score_omim_self': r['omim_self_phenodigm_score']['average_score'],
        'phenodigm_score_orphanet_self': r['orphanet_self_phenodigm_score']['average_score'],
    } for r in results])

# %%
score_df
# Out:
#             disease  ancestor_information_content  \
# 0     MONDO:0007167                     13.817717
# 1     MONDO:0008967                     10.742168
# 2     MONDO:0010547                     13.075760
# 3     MONDO:0008829                     12.094596
# 4     MONDO:0008620                     15.917020
# ...             ...                           ...
# 2092  MONDO:0013737                     14.584981
# 2093  MONDO:0013400                     13.380031
# 2094  MONDO:0008087                     12.853699
# 2095  MONDO:0011035                     12.761761
# 2096  MONDO:0008219                     11.246008
#
#       ancestor_information_content_omim_self  \
# 0                                  17.012315
# 1                                  17.482061
# 2                                  15.739035
# 3                                  16.958185
# 4                                  17.564011
# ...                                      ...
# 2092                               16.366311
# 2093                               16.584899
# 2094                               16.438208
# 2095                               17.142761
# 2096                               13.259643
#
#       ancestor_information_content_orphanet_self  jaccard_similarity  \
# 0                                      16.634543            0.772808
# 1                                      15.999629            0.571184
# 2                                      17.361246            0.806076
# 3                                      14.324329            0.744447
# 4                                      16.833542            0.802005
# ...                                          ...                 ...
# 2092                                   15.814934            0.869527
# 2093                                   16.951649            0.723024
# 2094                                   15.836758            0.773554
# 2095                                   15.570460            0.756597
# 2096                                   16.188893            0.825888
#
#       jaccard_similarity_omim_self  jaccard_similarity_orphanet_self  \
# 0                              1.0                               1.0
# 1                              1.0                               1.0
# 2                              1.0                               1.0
# 3                              1.0                               1.0
# 4                              1.0                               1.0
# ...                            ...                               ...
# 2092                           1.0                               1.0
# 2093                           1.0                               1.0
# 2094                           1.0                               1.0
# 2095                           1.0                               1.0
# 2096                           1.0                               1.0
#
#       phenodigm_score  phenodigm_score_omim_self  \
# 0            3.195493                   4.119417
# 1            2.379026                   4.179427
# 2            3.127593                   3.961502
# 3            2.995891                   4.114497
# 4            3.523730                   4.189954
# ...               ...                        ...
# 2092         3.507886                   4.040150
# 2093         3.057376                   4.064994
# 2094         3.086015                   4.044986
# 2095         3.059558                   4.135477
# 2096         3.001507                   3.612230
#
#       phenodigm_score_orphanet_self
# 0                          4.070784
# 1                          3.989719
# 2                          4.163276
# 3                          3.762925
# 4                          4.100690
# ...                             ...
# 2092                       3.967945
# 2093                       4.110144
# 2094                       3.972138
# 2095                       3.922544
# 2096                       4.011150
#
# [2097 rows x 10 columns]

# %% [markdown]
# Export the full results as JSON, export the score dataframe as tsv

# %%
# write results as json
with open('phenotype_profile_comparison_results.json', 'w') as f:
    json.dump(results, f)

# write results as tsv
score_df.to_csv('phenotype_profile_comparison_scores.tsv', sep='\t', index=False)
